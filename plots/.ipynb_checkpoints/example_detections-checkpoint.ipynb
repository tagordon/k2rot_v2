# %%
import pymc3 as pm
import distributions
import theano.tensor as tt
import exoplanet as xo
import matplotlib.pyplot as pl
# %matplotlib inline
from lightcurve import Lightcurve
import utils
from scipy.signal import medfilt
from astropy.stats import sigma_clip
import plotting
import imp

red = '#FE4365'
blue = '#00A9FF'
yellow = '#ECA25C'
green = '#3F9778'
darkblue = '#005D7F'

imp.reload(plotting)
imp.reload(utils)
# Out:
# <module 'utils' from '/Users/tgordon/research/spindown/utils.py'>

# %%
#201095854
#220133060
#201094315
#220139418
#220139565
#201094315
lc = Lightcurve.epic(211414351, season=18)
fig, axs = pl.subplots(3, 1, figsize=(8, 8))
plotting.lcplot(axs[0], lc, plot_outliers=True, plot_trend=True)
plotting.plotacf(axs[1], lc, acf_kwargs={"color": 'k', "linewidth": 3}, pk_kwargs={"linewidth": 1})
plotting.plotprior(axs[2], lc, normalize=True, linewidth=3, alpha=1)
# Out:
# /Users/tgordon/research/spindown/utils.py:44: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pks = pks[mask]
# /Users/tgordon/research/spindown/utils.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   prominences = prominences[mask]
# ...

# %%
y = lc.flux - utils.trend(lc.t, lc.flux, 2)
mask = sigma_clip(y-medfilt(y, kernel_size=5), sigma=3)
x = lc.t[mask.mask == False]
y = y[mask.mask == False]
yerr = np.std(y - medfilt(y, kernel_size=5))

with pm.Model() as model:
    
    mean = pm.Normal("mean", mu=np.mean(y), sd=np.std(y))
    yerr = pm.Normal("yerr", mu=yerr, sd=5.0)
    logamp = pm.Normal("logamp", mu=np.log(np.var(y)), sd=5)
    period = utils.periodprior(lc.t, lc.flux)
    logQ0 = pm.Uniform("logQ0", lower=-10, upper=10)
    logdQ = pm.Normal("logdQ", mu=2.0, sd=5.0)
    mix = pm.Uniform("mix", lower=0.0, upper=1.0)
    
    logS0 = pm.Normal("logS0", mu=np.log(np.var(y)), sd=5)
    dt = lc.t[-1] - lc.t[0]
    logw = pm.Uniform("logw", lower=-20, upper=0)
    
    # Set up the Gaussian Process model
    kernel = xo.gp.terms.RotationTerm(
        log_amp=logamp,
        period=period,
        log_Q0=logQ0,
        log_deltaQ=logdQ,
        mix=mix
    )
    kernel += xo.gp.terms.SHOTerm(
        log_S0 = logS0,
        log_w0 = logw,
        log_Q = -np.log(np.sqrt(2))
    )                  
                      
    gp = xo.gp.GP(kernel, x, yerr**2 * np.ones_like(x), mean=mean, J=6)
    gp.marginal("gp", observed = y)

    start = model.test_point
    map_soln = xo.optimize(start=start, verbose=True)
    trace = pm.sample(
        tune=2000,
        draws=1000,
        start=start,
        cores=2,
        chains=2,
        step=xo.get_dense_nuts_step(target_accept=0.9)
    )
# Out:
# /Users/tgordon/research/spindown/utils.py:44: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pks = pks[mask]
# /Users/tgordon/research/spindown/utils.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   prominences = prominences[mask]
# ...

# %%
plotting.cornerplot(lc, trace, smooth=True, truth_color=red);

# %%
import imp
imp.reload(plotting)

acf_kwargs = {'color': 'k', 'linewidth': 3}
pk_kwargs = {'color': red, 'linewidth': 1, 'linestyle': '--'}
all_acf_kwargs = {'peaks': True, 'acf_kwargs': acf_kwargs, 'pk_kwargs': pk_kwargs}

lc_kwargs = {'plot_outliers': True, 'plot_trend': True, 'uncertainties': False, 'highlight_color': blue, 'vline_color': blue}
prior_kwargs = {'color': red, 'linewidth': 2, 'normalize': True}
plotting.summaryplot(lc, trace, plot_period=True, plot_prior=True,
                     acf_kwargs=all_acf_kwargs, 
                     lc_kwargs=lc_kwargs, 
                     prior_kwargs=prior_kwargs);
pl.savefig('/Users/tgordon/Desktop/out.pdf')
# Out:
# /Users/tgordon/research/spindown/utils.py:44: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   pks = pks[mask]
# /Users/tgordon/research/spindown/utils.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   prominences = prominences[mask]
# ...

# %%
pm.summary(trace)
# Out:
#             mean        sd    hpd_3%   hpd_97%  mcse_mean  mcse_sd  ess_mean  \
# mean    1112.289  1992.928 -2547.377  5172.022    103.491   76.877     371.0
# yerr     607.696     4.722   599.186   615.932      0.255    0.181     342.0
# logamp    15.013     0.326    14.365    15.553      0.023    0.016     199.0
# logdQ     -5.180     1.698    -7.904    -2.377      0.240    0.180      50.0
# logS0     19.430     1.333    17.072    21.658      0.084    0.060     249.0
# P         13.484     9.302     1.741    30.248      1.565    1.211      35.0
# logQ0     -7.619     1.614    -9.999    -5.034      0.244    0.179      44.0
# mix        0.391     0.125     0.208     0.651      0.009    0.007     182.0
# logw      -1.497     0.514    -2.444    -0.608      0.031    0.022     281.0
#
#         ess_sd  ess_bulk  ess_tail  r_hat
# mean     337.0     370.0     424.0   1.02
# yerr     342.0     343.0     637.0   1.01
# logamp   199.0     194.0      54.0   1.01
# ...

# %%
np.savetxt("out.dat", pm.summary(trace).to_numpy().flatten()[None, :], fmt="%0.3f")

# %%
print("%0.3f".format(1.29398))
# Out:
# %0.3f

# %%
pm.summary(trace).to_numpy()
# Out:
# array([[ 1.112289e+03,  1.992928e+03, -2.547377e+03,  5.172022e+03,
#          1.034910e+02,  7.687700e+01,  3.710000e+02,  3.370000e+02,
#          3.700000e+02,  4.240000e+02,  1.020000e+00],
#        [ 6.076960e+02,  4.722000e+00,  5.991860e+02,  6.159320e+02,
#          2.550000e-01,  1.810000e-01,  3.420000e+02,  3.420000e+02,
#          3.430000e+02,  6.370000e+02,  1.010000e+00],
#        [ 1.501300e+01,  3.260000e-01,  1.436500e+01,  1.555300e+01,
#          2.300000e-02,  1.600000e-02,  1.990000e+02,  1.990000e+02,
#          1.940000e+02,  5.400000e+01,  1.010000e+00],
#        [-5.180000e+00,  1.698000e+00, -7.904000e+00, -2.377000e+00,
#          2.400000e-01,  1.800000e-01,  5.000000e+01,  4.500000e+01,
#          4.600000e+01,  9.300000e+01,  1.050000e+00],
#        [ 1.943000e+01,  1.333000e+00,  1.707200e+01,  2.165800e+01,
#          8.400000e-02,  6.000000e-02,  2.490000e+02,  2.490000e+02,
#          2.300000e+02,  3.270000e+02,  1.010000e+00],
# ...

# %%
fig1 = plotting.lcplot_withsummary(lc, trace);

fig2, axs = pl.subplots(3, 1, figsize=(8, 8))
plotting.lcplot(axs[0], lc, plot_outliers=True, plot_trend=True)
plotting.plotacf(axs[1], lc, acf_kwargs={"color": 'k', "linewidth": 3}, pk_kwargs={"linewidth": 1})
plotting.plotprior(axs[2], lc, normalize=True, linewidth=3, alpha=1)

# %%
fig1.gca()

# %%
fig, axs = pl.subplots(2, 1, figsize=(10, 6), gridspec_kw={'height_ratios': [1, 0.001]})
plotting.lcplot(axs[0], lc, trace=trace)

from pandas.plotting import table
axs[1].xaxis.set_visible(False)
axs[1].yaxis.set_visible(False)
table(axs[1], pm.summary(trace).round(3))
pl.tight_layout()
pl.savefig('/Users/tgordon/Desktop/tbl.pdf')

# %%
plotting.plotsummary(lc, trace)

# %%
import corner
samples = pm.trace_to_dataframe(trace)
_ = corner.corner(samples, truths=list(utils.modes(trace).values()))

# %%
pl.plot(lc.t, lc.flux, '.', color='k')
period = utils.modes(trace)['P']
for i in np.arange(np.int((lc.t[-1]-lc.t[0]) / period)+2):
    pl.axvline(min(lc.t) + i*period, alpha=0.3, linewidth=2)
pl.xlim((min(lc.t), max(lc.t)))

# %%
summary = pm.summary(trace)

# %%
utils.modes(trace)

# %%
summary['mode'] = list(utils.modes(trace).values())[:9]

# %%
import pandas as pd
summary.round(3)

# %%
from pandas.plotting import table
fig = pl.figure(figsize=(10, 0.2), frameon=False)
ax = fig.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
pl.axis('off')
pl.grid('off')
tbl = table(ax, summary.round(3))
tbl.set_fontsize(30)
pl.savefig("/Users/tgordon/Desktop/table.pdf", bbox_inches="tight")

# %%
utils.modes(trace)

# %%
P = utils.periodprior(lc.t, lc.flux / np.mean(lc.flux), detrend_order=2, min_period=0.5)

# %%
x = np.linspace(0, 70, 1000)
logp = P.logp(x).eval()

# %%
pl.plot(x, np.exp(logp))

# %%
lag, power = utils.autocorr(lc.t, lc.flux - utils.trend(lc.t, lc.flux, 2))
pl.plot(lag, power)

# %%
pl.plot(lc.t, lc.flux - utils.trend(lc.t, lc.flux, 2))

# %%
pl.plot(lc.t, lc.flux-medfilt(lc.flux, kernel_size=5))

# %%
from astropy.stats import sigma_clip
mask = sigma_clip(lc.flux-medfilt(lc.flux, kernel_size=5), sigma=3)

# %%
pl.plot(lc.t, lc.flux, '.')
pl.plot(lc.t[mask.mask], lc.flux[mask.mask], '.')

# %%
pl.plot(lc.t[mask.mask == False], lc.flux[mask.mask == False], '.')
pl.plot(lc.t[mask.mask], lc.flux[mask.mask], '.')

# %%
low, high = pm.stats.hpd(trace['P'], credible_interval=0.95)

# %%
low
# Out:
# 8.37051822393331
